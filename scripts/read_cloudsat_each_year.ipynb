# %% [markdown]
# ### This notebook reads in radiative flux profile from cloudsat satellite observations to calculate 5-day mean CRH for year 2007 as a example. Detailed methods are described in the subpplementary materials of Liu and Grise 2025.

# %%
import os
import numpy as np
from datetime import datetime, timedelta
from pyhdf.SD import SD, SDC
from pyhdf import HDF, VS
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd

# %%
# Helper function to read Vdata (Latitude, Longitude, Status)
def read_vdata(hdf_file, field_name):
    h = HDF.HDF(hdf_file)
    vs = h.vstart()
    try:
        field_id = vs.attach(vs.find(field_name))
        field_id.setfields(field_name)
        nrecs, _, _, _, _ = field_id.inquire()
        data = np.array(field_id.read(nRec=nrecs)).squeeze()
        field_id.detach()
    except Exception as e:
        print(f"Error reading {field_name}: {e}")
        data = None
    return data

# Function to read datasets from the HDF file (e.g., QR, Height)
def read_hdf_dataset(hdf_file, dataset_name):
    try:
        sd_file = SD(hdf_file, SDC.READ)
        data = sd_file.select(dataset_name)[:]
        sd_file.end()
    except Exception as e:
        print(f"Error reading {dataset_name}: {e}")
        data = None
    return data

# Function to apply quality control
def apply_quality_control(data):
    min_value = data.min()
    data = np.where(data <= min_value, np.nan, data)
    return data

# Function to interpolate and regrid the data
def regrid_data(variable, altitude, alt_grid):
    variable_sorted = np.flip(variable, axis=1)  # Flip along altitude
    altitude_sorted = np.flip(altitude, axis=1)  # Flip along altitude
    regridded_data = np.array([np.interp(alt_grid, altitude_sorted[j, :], variable_sorted[j, :], left=np.nan, right=np.nan) for j in range(len(variable))])
    return regridded_data

# Function to aggregate daily data
def aggregate_daily_data(dates, data_grid, unique_dates):
    numdays = len(unique_dates)
    aggregated_data = np.full((numdays, len(new_lat), len(new_lon), len(alt_grid)), np.nan)
    for k, day in enumerate(unique_dates):
        day_indices = np.where([date == day for date in dates])[0]
        if day_indices.size > 0:
            aggregated_data[k, :, :, :] = np.nanmean(data_grid[day_indices, :, :, :], axis=0)
    return aggregated_data

# %%
# Define grid settings
alt_grid = np.arange(0, 15.25, 0.25)
new_lat = np.arange(-88.75, 90, 2.5)
new_lon = np.arange(-178.75, 180, 2.5)

# Set base directory where CloudSat data is located
base_directory = "/bjerknes_raid5/cloudsat/2007"

# List all subdirectories (e.g., 001, 002, etc.)
subdirs = [os.path.join(base_directory, d) for d in sorted(os.listdir(base_directory)) if os.path.isdir(os.path.join(base_directory, d))]

# List all HDF files in the base directory and subdirectories
filelist = []
for subdir in subdirs:
    filelist += [os.path.join(subdir, f) for f in os.listdir(subdir) if f.endswith('.hdf')]

numfiles = len(filelist)
print(f"Number of files: {numfiles}")

# Main processing loop
QR_SWcloud_dia_grid_all = np.full((numfiles, len(new_lat), len(new_lon), len(alt_grid)), np.nan)
QR_LWcloud_dia_grid_all = np.full((numfiles, len(new_lat), len(new_lon), len(alt_grid)), np.nan)
numdate = np.zeros(len(subdirs))  # For 48 days in 2017
dates = []

for i, filepath in enumerate(filelist):
    print(f"Processing file {i+1}/{numfiles}: {filepath}")
    filename = os.path.basename(filepath)
    year = int(filename[:4])
    doy = int(filename[4:7])
    granule = filename.split('_')[1]
    filename_aux = filename.replace("_CS_2B-FLXHR-LIDAR_GRANULE_P2_","_CS_ECMWF-AUX_GRANULE_P1_")
    filepath_aux = '/bjerknes_raid5/cloudsat/aux/' + filename_aux
    date = datetime(year, 1, 1) + timedelta(days=doy - 1)
    dates.append(date)

    # Read geolocation and status fields
    latitude = read_vdata(filepath, 'Latitude')
    longitude = read_vdata(filepath, 'Longitude')
    status = read_vdata(filepath, 'Status')

    # Read Height and QR data from the HDF file
    altitude = read_hdf_dataset(filepath, 'Height') / 1000.0  # Convert to km
    FD = read_hdf_dataset(filepath, 'FD')
    FD = apply_quality_control(FD)
    FU = read_hdf_dataset(filepath, 'FU')
    FU = apply_quality_control(FU)
    FD_NC = read_hdf_dataset(filepath, 'FD_NC')
    FD_NC = apply_quality_control(FD_NC)
    FU_NC = read_hdf_dataset(filepath, 'FU_NC')
    FU_NC = apply_quality_control(FU_NC)

    FN = (FD - FU)/10.0
    FN_NC = (FD_NC - FU_NC)/10.0

    P = read_hdf_dataset(filepath_aux, 'Pressure')
    T = read_hdf_dataset(filepath_aux, 'Temperature')
    P = apply_quality_control(P)
    T = apply_quality_control(T)

    RHO = P/(287.0*T)

    cp = 1004
    dz = 240
    QR_SW_dia = -np.diff(FN[0, :, :])/ (cp*RHO*dz) * 86400  # units of K/day
    QR_LW_dia = -np.diff(FN[1, :, :])/ (cp*RHO*dz) * 86400

    QR_SWcs_dia = -np.diff(FN_NC[0, :, :])/ (cp*RHO*dz) * 86400  # units of K/day
    QR_LWcs_dia = -np.diff(FN_NC[1, :, :])/ (cp*RHO*dz) * 86400

    QR_SWcloud_dia = QR_SW_dia - QR_SWcs_dia
    QR_LWcloud_dia = QR_LW_dia - QR_LWcs_dia

    # Regrid QRS and QRL to standard altitude grid
    QR_SWcloud_dia_regrid = regrid_data(QR_SWcloud_dia, altitude, alt_grid)
    QR_LWcloud_dia_regrid = regrid_data(QR_LWcloud_dia, altitude, alt_grid)

    # Grid the data into latitude and longitude bins
    QR_SWcloud_dia_grid = np.full((len(new_lat), len(new_lon), len(alt_grid)), np.nan)
    QR_LWcloud_dia_grid = np.full((len(new_lat), len(new_lon), len(alt_grid)), np.nan)

    for m in range(len(new_lat) - 1):
        for n in range(len(new_lon) - 1):
            indices = np.where(
                (latitude >= new_lat[m]) & (latitude < new_lat[m + 1]) &
                (longitude >= new_lon[n]) & (longitude < new_lon[n + 1])
            )[0]
            if indices.size > 0:
                QR_SWcloud_dia_grid[m + 1, n + 1, :] = np.nanmean(QR_SWcloud_dia_regrid[indices, :], axis=0)
                QR_LWcloud_dia_grid[m + 1, n + 1, :] = np.nanmean(QR_LWcloud_dia_regrid[indices, :], axis=0)

    # Store the gridded data
    QR_SWcloud_dia_grid_all[i, :, :, :] = QR_SWcloud_dia_grid
    QR_LWcloud_dia_grid_all[i, :, :, :] = QR_LWcloud_dia_grid


# Compute daily zonal mean (for QRL and QRS)
unique_dates = np.unique(dates)
QR_SWcloud_dia_grid_daily = aggregate_daily_data(dates, QR_SWcloud_dia_grid_all, unique_dates)
QR_LWcloud_dia_grid_daily = aggregate_daily_data(dates, QR_LWcloud_dia_grid_all, unique_dates)

QR_SWcloud_dia_grid_daily_zonalmean = np.nanmean(QR_SWcloud_dia_grid_daily, axis=2)
QR_LWcloud_dia_grid_daily_zonalmean = np.nanmean(QR_LWcloud_dia_grid_daily, axis=2)

# Save data to a numpy .npz file
np.savez('QR_cloud_2007.npz',
         QR_SWcloud_dia_grid_daily=QR_SWcloud_dia_grid_daily,
         QR_LWcloud_dia_grid_daily=QR_LWcloud_dia_grid_daily,
         QR_SWcloud_dia_grid_daily_zonalmean=QR_SWcloud_dia_grid_daily_zonalmean,
         QR_LWcloud_dia_grid_daily_zonalmean=QR_LWcloud_dia_grid_daily_zonalmean,
         alt_grid=alt_grid,
         new_lat=new_lat,
         new_lon=new_lon,
         numdate=unique_dates)

print("Processing complete. Data saved to QR_cloud_2007.npz")
# Out:
# Number of files: 4702
# Processing file 1/4702: /bjerknes_raid5/cloudsat/2007/001/2007001040927_03609_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# /tmp/ipykernel_53193/3031461719.py:89: RuntimeWarning: Mean of empty slice
#   QR_SWcloud_dia_grid[m + 1, n + 1, :] = np.nanmean(QR_SWcloud_dia_regrid[indices, :], axis=0)
# /tmp/ipykernel_53193/3031461719.py:90: RuntimeWarning: Mean of empty slice
#   QR_LWcloud_dia_grid[m + 1, n + 1, :] = np.nanmean(QR_LWcloud_dia_regrid[indices, :], axis=0)
# Processing file 2/4702: /bjerknes_raid5/cloudsat/2007/001/2007001122353_03614_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 3/4702: /bjerknes_raid5/cloudsat/2007/001/2007001203818_03619_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4/4702: /bjerknes_raid5/cloudsat/2007/001/2007001072713_03611_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 5/4702: /bjerknes_raid5/cloudsat/2007/001/2007001172031_03617_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 6/4702: /bjerknes_raid5/cloudsat/2007/001/2007001090607_03612_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 7/4702: /bjerknes_raid5/cloudsat/2007/001/2007001221711_03620_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 8/4702: /bjerknes_raid5/cloudsat/2007/001/2007001235604_03621_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 9/4702: /bjerknes_raid5/cloudsat/2007/001/2007001023034_03608_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 10/4702: /bjerknes_raid5/cloudsat/2007/001/2007001154138_03616_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 11/4702: /bjerknes_raid5/cloudsat/2007/001/2007001005141_03607_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 12/4702: /bjerknes_raid5/cloudsat/2007/001/2007001054820_03610_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 13/4702: /bjerknes_raid5/cloudsat/2007/001/2007001185925_03618_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 14/4702: /bjerknes_raid5/cloudsat/2007/001/2007001140246_03615_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 15/4702: /bjerknes_raid5/cloudsat/2007/002/2007002212133_03634_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 16/4702: /bjerknes_raid5/cloudsat/2007/002/2007002094922_03627_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 17/4702: /bjerknes_raid5/cloudsat/2007/002/2007002230026_03635_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 18/4702: /bjerknes_raid5/cloudsat/2007/002/2007002194240_03633_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 19/4702: /bjerknes_raid5/cloudsat/2007/002/2007002045243_03624_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 20/4702: /bjerknes_raid5/cloudsat/2007/002/2007002180347_03632_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 21/4702: /bjerknes_raid5/cloudsat/2007/002/2007002130708_03629_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 22/4702: /bjerknes_raid5/cloudsat/2007/002/2007002144601_03630_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 23/4702: /bjerknes_raid5/cloudsat/2007/002/2007002063136_03625_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 24/4702: /bjerknes_raid5/cloudsat/2007/002/2007002031350_03623_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 25/4702: /bjerknes_raid5/cloudsat/2007/002/2007002013457_03622_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 26/4702: /bjerknes_raid5/cloudsat/2007/002/2007002112815_03628_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 27/4702: /bjerknes_raid5/cloudsat/2007/002/2007002162454_03631_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 28/4702: /bjerknes_raid5/cloudsat/2007/002/2007002081029_03626_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 29/4702: /bjerknes_raid5/cloudsat/2007/003/2007003003919_03636_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 30/4702: /bjerknes_raid5/cloudsat/2007/003/2007003234342_03650_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 31/4702: /bjerknes_raid5/cloudsat/2007/003/2007003220448_03649_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 32/4702: /bjerknes_raid5/cloudsat/2007/003/2007003170809_03646_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 33/4702: /bjerknes_raid5/cloudsat/2007/003/2007003053558_03639_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 34/4702: /bjerknes_raid5/cloudsat/2007/003/2007003085344_03641_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 35/4702: /bjerknes_raid5/cloudsat/2007/003/2007003135023_03644_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 36/4702: /bjerknes_raid5/cloudsat/2007/003/2007003184702_03647_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 37/4702: /bjerknes_raid5/cloudsat/2007/003/2007003071451_03640_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 38/4702: /bjerknes_raid5/cloudsat/2007/003/2007003152916_03645_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 39/4702: /bjerknes_raid5/cloudsat/2007/003/2007003202555_03648_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 40/4702: /bjerknes_raid5/cloudsat/2007/003/2007003103237_03642_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 41/4702: /bjerknes_raid5/cloudsat/2007/003/2007003121130_03643_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 42/4702: /bjerknes_raid5/cloudsat/2007/003/2007003021812_03637_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 43/4702: /bjerknes_raid5/cloudsat/2007/004/2007004210911_03663_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 44/4702: /bjerknes_raid5/cloudsat/2007/004/2007004093700_03656_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 45/4702: /bjerknes_raid5/cloudsat/2007/004/2007004143339_03659_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 46/4702: /bjerknes_raid5/cloudsat/2007/004/2007004125446_03658_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 47/4702: /bjerknes_raid5/cloudsat/2007/004/2007004075806_03655_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 48/4702: /bjerknes_raid5/cloudsat/2007/004/2007004193018_03662_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 49/4702: /bjerknes_raid5/cloudsat/2007/004/2007004111553_03657_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 50/4702: /bjerknes_raid5/cloudsat/2007/004/2007004175125_03661_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 51/4702: /bjerknes_raid5/cloudsat/2007/004/2007004030127_03652_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 52/4702: /bjerknes_raid5/cloudsat/2007/004/2007004012234_03651_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 53/4702: /bjerknes_raid5/cloudsat/2007/004/2007004044020_03653_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 54/4702: /bjerknes_raid5/cloudsat/2007/004/2007004224804_03664_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 55/4702: /bjerknes_raid5/cloudsat/2007/004/2007004161232_03660_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 56/4702: /bjerknes_raid5/cloudsat/2007/004/2007004061913_03654_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 57/4702: /bjerknes_raid5/cloudsat/2007/005/2007005084122_03670_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 58/4702: /bjerknes_raid5/cloudsat/2007/005/2007005165547_03675_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 59/4702: /bjerknes_raid5/cloudsat/2007/005/2007005002657_03665_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 60/4702: /bjerknes_raid5/cloudsat/2007/006/2007006191755_03691_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 61/4702: /bjerknes_raid5/cloudsat/2007/006/2007006092437_03685_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 62/4702: /bjerknes_raid5/cloudsat/2007/006/2007006024905_03681_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 63/4702: /bjerknes_raid5/cloudsat/2007/006/2007006124223_03687_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 64/4702: /bjerknes_raid5/cloudsat/2007/006/2007006074544_03684_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 65/4702: /bjerknes_raid5/cloudsat/2007/006/2007006011012_03680_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 66/4702: /bjerknes_raid5/cloudsat/2007/006/2007006110330_03686_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 67/4702: /bjerknes_raid5/cloudsat/2007/006/2007006223541_03693_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 68/4702: /bjerknes_raid5/cloudsat/2007/006/2007006173902_03690_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 69/4702: /bjerknes_raid5/cloudsat/2007/006/2007006160009_03689_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 70/4702: /bjerknes_raid5/cloudsat/2007/006/2007006205648_03692_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 71/4702: /bjerknes_raid5/cloudsat/2007/006/2007006060651_03683_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 72/4702: /bjerknes_raid5/cloudsat/2007/006/2007006042758_03682_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 73/4702: /bjerknes_raid5/cloudsat/2007/006/2007006142116_03688_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 74/4702: /bjerknes_raid5/cloudsat/2007/007/2007007214004_03707_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 75/4702: /bjerknes_raid5/cloudsat/2007/007/2007007051113_03697_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 76/4702: /bjerknes_raid5/cloudsat/2007/007/2007007182218_03705_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 77/4702: /bjerknes_raid5/cloudsat/2007/007/2007007132539_03702_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 78/4702: /bjerknes_raid5/cloudsat/2007/007/2007007100753_03700_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 79/4702: /bjerknes_raid5/cloudsat/2007/007/2007007231857_03708_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 80/4702: /bjerknes_raid5/cloudsat/2007/007/2007007114646_03701_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 81/4702: /bjerknes_raid5/cloudsat/2007/007/2007007150431_03703_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 82/4702: /bjerknes_raid5/cloudsat/2007/007/2007007001434_03694_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 83/4702: /bjerknes_raid5/cloudsat/2007/007/2007007082900_03699_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 84/4702: /bjerknes_raid5/cloudsat/2007/007/2007007164324_03704_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 85/4702: /bjerknes_raid5/cloudsat/2007/007/2007007015327_03695_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 86/4702: /bjerknes_raid5/cloudsat/2007/007/2007007033220_03696_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 87/4702: /bjerknes_raid5/cloudsat/2007/007/2007007200111_03706_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 88/4702: /bjerknes_raid5/cloudsat/2007/008/2007008154747_03718_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 89/4702: /bjerknes_raid5/cloudsat/2007/008/2007008190533_03720_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 90/4702: /bjerknes_raid5/cloudsat/2007/008/2007008105108_03715_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 91/4702: /bjerknes_raid5/cloudsat/2007/008/2007008041536_03711_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 92/4702: /bjerknes_raid5/cloudsat/2007/008/2007008005750_03709_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 93/4702: /bjerknes_raid5/cloudsat/2007/008/2007008204426_03721_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 94/4702: /bjerknes_raid5/cloudsat/2007/008/2007008091215_03714_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 95/4702: /bjerknes_raid5/cloudsat/2007/008/2007008023643_03710_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 96/4702: /bjerknes_raid5/cloudsat/2007/008/2007008172640_03719_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 97/4702: /bjerknes_raid5/cloudsat/2007/008/2007008055429_03712_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 98/4702: /bjerknes_raid5/cloudsat/2007/008/2007008222319_03722_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 99/4702: /bjerknes_raid5/cloudsat/2007/008/2007008140854_03717_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 100/4702: /bjerknes_raid5/cloudsat/2007/008/2007008123001_03716_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 101/4702: /bjerknes_raid5/cloudsat/2007/008/2007008073322_03713_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 102/4702: /bjerknes_raid5/cloudsat/2007/009/2007009145209_03732_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 103/4702: /bjerknes_raid5/cloudsat/2007/009/2007009230634_03737_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 104/4702: /bjerknes_raid5/cloudsat/2007/009/2007009212741_03736_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 105/4702: /bjerknes_raid5/cloudsat/2007/009/2007009081637_03728_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 106/4702: /bjerknes_raid5/cloudsat/2007/009/2007009031958_03725_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 107/4702: /bjerknes_raid5/cloudsat/2007/009/2007009194848_03735_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 108/4702: /bjerknes_raid5/cloudsat/2007/009/2007009014105_03724_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 109/4702: /bjerknes_raid5/cloudsat/2007/009/2007009163102_03733_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 110/4702: /bjerknes_raid5/cloudsat/2007/009/2007009095530_03729_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 111/4702: /bjerknes_raid5/cloudsat/2007/009/2007009000212_03723_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 112/4702: /bjerknes_raid5/cloudsat/2007/009/2007009113423_03730_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 113/4702: /bjerknes_raid5/cloudsat/2007/009/2007009180955_03734_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 114/4702: /bjerknes_raid5/cloudsat/2007/009/2007009045851_03726_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 115/4702: /bjerknes_raid5/cloudsat/2007/009/2007009063744_03727_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 116/4702: /bjerknes_raid5/cloudsat/2007/009/2007009131316_03731_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 117/4702: /bjerknes_raid5/cloudsat/2007/010/2007010153524_03747_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 118/4702: /bjerknes_raid5/cloudsat/2007/010/2007010171417_03748_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 119/4702: /bjerknes_raid5/cloudsat/2007/010/2007010072059_03742_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 120/4702: /bjerknes_raid5/cloudsat/2007/010/2007010040313_03740_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 121/4702: /bjerknes_raid5/cloudsat/2007/010/2007010054206_03741_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 122/4702: /bjerknes_raid5/cloudsat/2007/010/2007010234949_03752_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 123/4702: /bjerknes_raid5/cloudsat/2007/010/2007010085952_03743_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 124/4702: /bjerknes_raid5/cloudsat/2007/010/2007010121738_03745_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 125/4702: /bjerknes_raid5/cloudsat/2007/010/2007010103845_03744_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 126/4702: /bjerknes_raid5/cloudsat/2007/010/2007010135631_03746_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 127/4702: /bjerknes_raid5/cloudsat/2007/010/2007010221057_03751_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 128/4702: /bjerknes_raid5/cloudsat/2007/010/2007010185310_03749_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 129/4702: /bjerknes_raid5/cloudsat/2007/010/2007010022420_03739_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 130/4702: /bjerknes_raid5/cloudsat/2007/010/2007010004527_03738_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 131/4702: /bjerknes_raid5/cloudsat/2007/011/2007011030735_03754_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 132/4702: /bjerknes_raid5/cloudsat/2007/011/2007011130054_03760_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 133/4702: /bjerknes_raid5/cloudsat/2007/011/2007011080415_03757_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 134/4702: /bjerknes_raid5/cloudsat/2007/011/2007011094308_03758_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 135/4702: /bjerknes_raid5/cloudsat/2007/011/2007011225412_03766_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 136/4702: /bjerknes_raid5/cloudsat/2007/011/2007011012842_03753_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 137/4702: /bjerknes_raid5/cloudsat/2007/011/2007011193626_03764_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 138/4702: /bjerknes_raid5/cloudsat/2007/011/2007011161840_03762_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 139/4702: /bjerknes_raid5/cloudsat/2007/011/2007011211519_03765_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 140/4702: /bjerknes_raid5/cloudsat/2007/011/2007011143947_03761_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 141/4702: /bjerknes_raid5/cloudsat/2007/011/2007011044628_03755_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 142/4702: /bjerknes_raid5/cloudsat/2007/011/2007011112201_03759_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 143/4702: /bjerknes_raid5/cloudsat/2007/011/2007011062521_03756_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 144/4702: /bjerknes_raid5/cloudsat/2007/012/2007012134409_03775_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 145/4702: /bjerknes_raid5/cloudsat/2007/012/2007012201941_03779_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 146/4702: /bjerknes_raid5/cloudsat/2007/012/2007012152302_03776_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 147/4702: /bjerknes_raid5/cloudsat/2007/012/2007012215834_03780_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 148/4702: /bjerknes_raid5/cloudsat/2007/012/2007012035051_03769_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 149/4702: /bjerknes_raid5/cloudsat/2007/012/2007012084730_03772_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 150/4702: /bjerknes_raid5/cloudsat/2007/012/2007012070837_03771_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 151/4702: /bjerknes_raid5/cloudsat/2007/012/2007012102623_03773_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 152/4702: /bjerknes_raid5/cloudsat/2007/012/2007012233727_03781_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 153/4702: /bjerknes_raid5/cloudsat/2007/012/2007012021158_03768_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 154/4702: /bjerknes_raid5/cloudsat/2007/012/2007012052944_03770_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 155/4702: /bjerknes_raid5/cloudsat/2007/012/2007012003305_03767_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 156/4702: /bjerknes_raid5/cloudsat/2007/012/2007012184048_03778_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 157/4702: /bjerknes_raid5/cloudsat/2007/012/2007012170155_03777_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 158/4702: /bjerknes_raid5/cloudsat/2007/012/2007012120516_03774_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 159/4702: /bjerknes_raid5/cloudsat/2007/013/2007013210256_03794_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 160/4702: /bjerknes_raid5/cloudsat/2007/013/2007013061259_03785_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 161/4702: /bjerknes_raid5/cloudsat/2007/013/2007013110938_03788_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 162/4702: /bjerknes_raid5/cloudsat/2007/013/2007013075152_03786_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 163/4702: /bjerknes_raid5/cloudsat/2007/013/2007013192403_03793_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 164/4702: /bjerknes_raid5/cloudsat/2007/013/2007013224149_03795_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 165/4702: /bjerknes_raid5/cloudsat/2007/013/2007013093045_03787_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 166/4702: /bjerknes_raid5/cloudsat/2007/013/2007013124831_03789_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 167/4702: /bjerknes_raid5/cloudsat/2007/013/2007013025513_03783_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 168/4702: /bjerknes_raid5/cloudsat/2007/013/2007013043406_03784_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 169/4702: /bjerknes_raid5/cloudsat/2007/013/2007013011620_03782_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 170/4702: /bjerknes_raid5/cloudsat/2007/013/2007013142724_03790_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 171/4702: /bjerknes_raid5/cloudsat/2007/013/2007013160617_03791_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 172/4702: /bjerknes_raid5/cloudsat/2007/013/2007013174510_03792_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 173/4702: /bjerknes_raid5/cloudsat/2007/014/2007014065614_03800_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 174/4702: /bjerknes_raid5/cloudsat/2007/014/2007014214611_03809_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 175/4702: /bjerknes_raid5/cloudsat/2007/014/2007014051721_03799_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 176/4702: /bjerknes_raid5/cloudsat/2007/014/2007014164932_03806_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 177/4702: /bjerknes_raid5/cloudsat/2007/014/2007014101400_03802_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 178/4702: /bjerknes_raid5/cloudsat/2007/014/2007014232504_03810_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 179/4702: /bjerknes_raid5/cloudsat/2007/014/2007014015935_03797_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 180/4702: /bjerknes_raid5/cloudsat/2007/014/2007014182825_03807_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 181/4702: /bjerknes_raid5/cloudsat/2007/014/2007014115253_03803_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 182/4702: /bjerknes_raid5/cloudsat/2007/014/2007014151039_03805_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 183/4702: /bjerknes_raid5/cloudsat/2007/014/2007014083507_03801_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 184/4702: /bjerknes_raid5/cloudsat/2007/014/2007014200718_03808_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 185/4702: /bjerknes_raid5/cloudsat/2007/014/2007014133146_03804_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 186/4702: /bjerknes_raid5/cloudsat/2007/014/2007014033828_03798_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 187/4702: /bjerknes_raid5/cloudsat/2007/014/2007014002042_03796_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 188/4702: /bjerknes_raid5/cloudsat/2007/015/2007015010357_03811_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 189/4702: /bjerknes_raid5/cloudsat/2007/015/2007015042143_03813_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 190/4702: /bjerknes_raid5/cloudsat/2007/015/2007015024250_03812_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 191/4702: /bjerknes_raid5/cloudsat/2007/017/2007017185919_03851_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 192/4702: /bjerknes_raid5/cloudsat/2007/017/2007017122347_03847_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 193/4702: /bjerknes_raid5/cloudsat/2007/017/2007017235558_03854_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 194/4702: /bjerknes_raid5/cloudsat/2007/017/2007017221705_03853_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 195/4702: /bjerknes_raid5/cloudsat/2007/017/2007017154133_03849_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 196/4702: /bjerknes_raid5/cloudsat/2007/017/2007017172026_03850_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 197/4702: /bjerknes_raid5/cloudsat/2007/017/2007017203812_03852_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 198/4702: /bjerknes_raid5/cloudsat/2007/017/2007017140240_03848_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 199/4702: /bjerknes_raid5/cloudsat/2007/018/2007018194236_03866_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 200/4702: /bjerknes_raid5/cloudsat/2007/018/2007018230022_03868_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 201/4702: /bjerknes_raid5/cloudsat/2007/018/2007018180343_03865_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 202/4702: /bjerknes_raid5/cloudsat/2007/018/2007018094917_03860_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 203/4702: /bjerknes_raid5/cloudsat/2007/018/2007018112810_03861_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 204/4702: /bjerknes_raid5/cloudsat/2007/018/2007018162449_03864_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 205/4702: /bjerknes_raid5/cloudsat/2007/018/2007018081024_03859_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 206/4702: /bjerknes_raid5/cloudsat/2007/018/2007018063131_03858_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 207/4702: /bjerknes_raid5/cloudsat/2007/018/2007018045238_03857_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 208/4702: /bjerknes_raid5/cloudsat/2007/018/2007018031344_03856_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 209/4702: /bjerknes_raid5/cloudsat/2007/018/2007018144556_03863_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 210/4702: /bjerknes_raid5/cloudsat/2007/018/2007018212129_03867_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 211/4702: /bjerknes_raid5/cloudsat/2007/018/2007018013452_03855_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 212/4702: /bjerknes_raid5/cloudsat/2007/018/2007018130703_03862_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 213/4702: /bjerknes_raid5/cloudsat/2007/019/2007019121127_03876_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 214/4702: /bjerknes_raid5/cloudsat/2007/019/2007019152913_03878_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 215/4702: /bjerknes_raid5/cloudsat/2007/019/2007019071448_03873_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 216/4702: /bjerknes_raid5/cloudsat/2007/019/2007019184659_03880_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 217/4702: /bjerknes_raid5/cloudsat/2007/019/2007019035701_03871_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 218/4702: /bjerknes_raid5/cloudsat/2007/019/2007019021808_03870_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 219/4702: /bjerknes_raid5/cloudsat/2007/019/2007019170806_03879_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 220/4702: /bjerknes_raid5/cloudsat/2007/019/2007019234339_03883_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 221/4702: /bjerknes_raid5/cloudsat/2007/019/2007019135020_03877_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 222/4702: /bjerknes_raid5/cloudsat/2007/019/2007019053554_03872_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 223/4702: /bjerknes_raid5/cloudsat/2007/019/2007019202553_03881_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 224/4702: /bjerknes_raid5/cloudsat/2007/019/2007019003915_03869_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 225/4702: /bjerknes_raid5/cloudsat/2007/019/2007019220446_03882_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 226/4702: /bjerknes_raid5/cloudsat/2007/019/2007019103234_03875_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 227/4702: /bjerknes_raid5/cloudsat/2007/019/2007019085341_03874_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 228/4702: /bjerknes_raid5/cloudsat/2007/020/2007020061911_03887_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 229/4702: /bjerknes_raid5/cloudsat/2007/020/2007020143337_03892_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 230/4702: /bjerknes_raid5/cloudsat/2007/020/2007020075804_03888_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 231/4702: /bjerknes_raid5/cloudsat/2007/020/2007020224803_03897_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 232/4702: /bjerknes_raid5/cloudsat/2007/020/2007020161230_03893_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 233/4702: /bjerknes_raid5/cloudsat/2007/020/2007020210909_03896_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 234/4702: /bjerknes_raid5/cloudsat/2007/020/2007020030125_03885_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 235/4702: /bjerknes_raid5/cloudsat/2007/020/2007020125444_03891_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 236/4702: /bjerknes_raid5/cloudsat/2007/020/2007020193016_03895_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 237/4702: /bjerknes_raid5/cloudsat/2007/020/2007020093658_03889_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 238/4702: /bjerknes_raid5/cloudsat/2007/020/2007020111551_03890_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 239/4702: /bjerknes_raid5/cloudsat/2007/020/2007020175123_03894_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 240/4702: /bjerknes_raid5/cloudsat/2007/020/2007020044018_03886_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 241/4702: /bjerknes_raid5/cloudsat/2007/020/2007020012232_03884_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 242/4702: /bjerknes_raid5/cloudsat/2007/021/2007021052335_03901_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 243/4702: /bjerknes_raid5/cloudsat/2007/021/2007021151654_03907_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 244/4702: /bjerknes_raid5/cloudsat/2007/021/2007021084121_03903_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 245/4702: /bjerknes_raid5/cloudsat/2007/021/2007021102015_03904_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 246/4702: /bjerknes_raid5/cloudsat/2007/021/2007021201333_03910_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 247/4702: /bjerknes_raid5/cloudsat/2007/021/2007021215226_03911_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 248/4702: /bjerknes_raid5/cloudsat/2007/021/2007021115908_03905_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 249/4702: /bjerknes_raid5/cloudsat/2007/021/2007021070228_03902_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 250/4702: /bjerknes_raid5/cloudsat/2007/021/2007021165547_03908_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 251/4702: /bjerknes_raid5/cloudsat/2007/021/2007021133801_03906_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 252/4702: /bjerknes_raid5/cloudsat/2007/021/2007021020549_03899_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 253/4702: /bjerknes_raid5/cloudsat/2007/021/2007021233119_03912_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 254/4702: /bjerknes_raid5/cloudsat/2007/021/2007021183440_03909_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 255/4702: /bjerknes_raid5/cloudsat/2007/021/2007021034442_03900_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 256/4702: /bjerknes_raid5/cloudsat/2007/021/2007021002656_03898_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 257/4702: /bjerknes_raid5/cloudsat/2007/022/2007022092438_03918_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 258/4702: /bjerknes_raid5/cloudsat/2007/022/2007022173904_03923_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 259/4702: /bjerknes_raid5/cloudsat/2007/022/2007022060652_03916_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 260/4702: /bjerknes_raid5/cloudsat/2007/022/2007022110331_03919_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 261/4702: /bjerknes_raid5/cloudsat/2007/022/2007022024906_03914_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 262/4702: /bjerknes_raid5/cloudsat/2007/022/2007022160010_03922_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 263/4702: /bjerknes_raid5/cloudsat/2007/022/2007022074545_03917_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 264/4702: /bjerknes_raid5/cloudsat/2007/022/2007022223543_03926_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 265/4702: /bjerknes_raid5/cloudsat/2007/022/2007022191757_03924_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 266/4702: /bjerknes_raid5/cloudsat/2007/022/2007022124224_03920_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 267/4702: /bjerknes_raid5/cloudsat/2007/022/2007022205650_03925_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 268/4702: /bjerknes_raid5/cloudsat/2007/022/2007022011012_03913_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 269/4702: /bjerknes_raid5/cloudsat/2007/022/2007022142117_03921_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 270/4702: /bjerknes_raid5/cloudsat/2007/022/2007022042759_03915_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 271/4702: /bjerknes_raid5/cloudsat/2007/023/2007023182220_03938_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 272/4702: /bjerknes_raid5/cloudsat/2007/023/2007023200114_03939_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 273/4702: /bjerknes_raid5/cloudsat/2007/023/2007023065008_03931_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 274/4702: /bjerknes_raid5/cloudsat/2007/023/2007023114648_03934_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 275/4702: /bjerknes_raid5/cloudsat/2007/023/2007023001436_03927_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 276/4702: /bjerknes_raid5/cloudsat/2007/023/2007023051115_03930_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 277/4702: /bjerknes_raid5/cloudsat/2007/023/2007023164327_03937_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 278/4702: /bjerknes_raid5/cloudsat/2007/023/2007023214007_03940_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 279/4702: /bjerknes_raid5/cloudsat/2007/023/2007023015329_03928_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 280/4702: /bjerknes_raid5/cloudsat/2007/023/2007023132541_03935_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 281/4702: /bjerknes_raid5/cloudsat/2007/023/2007023100755_03933_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 282/4702: /bjerknes_raid5/cloudsat/2007/023/2007023033222_03929_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 283/4702: /bjerknes_raid5/cloudsat/2007/023/2007023150434_03936_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 284/4702: /bjerknes_raid5/cloudsat/2007/023/2007023082902_03932_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 285/4702: /bjerknes_raid5/cloudsat/2007/023/2007023231900_03941_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 286/4702: /bjerknes_raid5/cloudsat/2007/024/2007024140858_03950_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 287/4702: /bjerknes_raid5/cloudsat/2007/024/2007024073325_03946_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 288/4702: /bjerknes_raid5/cloudsat/2007/024/2007024041539_03944_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 289/4702: /bjerknes_raid5/cloudsat/2007/024/2007024154751_03951_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 290/4702: /bjerknes_raid5/cloudsat/2007/024/2007024055432_03945_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 291/4702: /bjerknes_raid5/cloudsat/2007/024/2007024204430_03954_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 292/4702: /bjerknes_raid5/cloudsat/2007/024/2007024123005_03949_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 293/4702: /bjerknes_raid5/cloudsat/2007/024/2007024105112_03948_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 294/4702: /bjerknes_raid5/cloudsat/2007/024/2007024091219_03947_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 295/4702: /bjerknes_raid5/cloudsat/2007/024/2007024005753_03942_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 296/4702: /bjerknes_raid5/cloudsat/2007/024/2007024190537_03953_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 297/4702: /bjerknes_raid5/cloudsat/2007/024/2007024172644_03952_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 298/4702: /bjerknes_raid5/cloudsat/2007/024/2007024222324_03955_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 299/4702: /bjerknes_raid5/cloudsat/2007/024/2007024023646_03943_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 300/4702: /bjerknes_raid5/cloudsat/2007/025/2007025212747_03969_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 301/4702: /bjerknes_raid5/cloudsat/2007/025/2007025032003_03958_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 302/4702: /bjerknes_raid5/cloudsat/2007/025/2007025194854_03968_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 303/4702: /bjerknes_raid5/cloudsat/2007/025/2007025113428_03963_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 304/4702: /bjerknes_raid5/cloudsat/2007/025/2007025014110_03957_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 305/4702: /bjerknes_raid5/cloudsat/2007/025/2007025230640_03970_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 306/4702: /bjerknes_raid5/cloudsat/2007/025/2007025063749_03960_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 307/4702: /bjerknes_raid5/cloudsat/2007/025/2007025131322_03964_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 308/4702: /bjerknes_raid5/cloudsat/2007/025/2007025163108_03966_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 309/4702: /bjerknes_raid5/cloudsat/2007/025/2007025145215_03965_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 310/4702: /bjerknes_raid5/cloudsat/2007/025/2007025000217_03956_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 311/4702: /bjerknes_raid5/cloudsat/2007/025/2007025045856_03959_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 312/4702: /bjerknes_raid5/cloudsat/2007/025/2007025181001_03967_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 313/4702: /bjerknes_raid5/cloudsat/2007/026/2007026121745_03978_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 314/4702: /bjerknes_raid5/cloudsat/2007/026/2007026072106_03975_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 315/4702: /bjerknes_raid5/cloudsat/2007/026/2007026221104_03984_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 316/4702: /bjerknes_raid5/cloudsat/2007/026/2007026135638_03979_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 317/4702: /bjerknes_raid5/cloudsat/2007/026/2007026234957_03985_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 318/4702: /bjerknes_raid5/cloudsat/2007/026/2007026040320_03973_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 319/4702: /bjerknes_raid5/cloudsat/2007/026/2007026153531_03980_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 320/4702: /bjerknes_raid5/cloudsat/2007/026/2007026004533_03971_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 321/4702: /bjerknes_raid5/cloudsat/2007/026/2007026203211_03983_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 322/4702: /bjerknes_raid5/cloudsat/2007/026/2007026022426_03972_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 323/4702: /bjerknes_raid5/cloudsat/2007/026/2007026171424_03981_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 324/4702: /bjerknes_raid5/cloudsat/2007/026/2007026185318_03982_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 325/4702: /bjerknes_raid5/cloudsat/2007/026/2007026054213_03974_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 326/4702: /bjerknes_raid5/cloudsat/2007/027/2007027143955_03994_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 327/4702: /bjerknes_raid5/cloudsat/2007/027/2007027044636_03988_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 328/4702: /bjerknes_raid5/cloudsat/2007/027/2007027211527_03998_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 329/4702: /bjerknes_raid5/cloudsat/2007/027/2007027161848_03995_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 330/4702: /bjerknes_raid5/cloudsat/2007/027/2007027080423_03990_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 331/4702: /bjerknes_raid5/cloudsat/2007/027/2007027130102_03993_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 332/4702: /bjerknes_raid5/cloudsat/2007/027/2007027062529_03989_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 333/4702: /bjerknes_raid5/cloudsat/2007/027/2007027012850_03986_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 334/4702: /bjerknes_raid5/cloudsat/2007/027/2007027030743_03987_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 335/4702: /bjerknes_raid5/cloudsat/2007/027/2007027112209_03992_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 336/4702: /bjerknes_raid5/cloudsat/2007/027/2007027175741_03996_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 337/4702: /bjerknes_raid5/cloudsat/2007/027/2007027193634_03997_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 338/4702: /bjerknes_raid5/cloudsat/2007/027/2007027094316_03991_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 339/4702: /bjerknes_raid5/cloudsat/2007/027/2007027225421_03999_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 340/4702: /bjerknes_raid5/cloudsat/2007/028/2007028102632_04006_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 341/4702: /bjerknes_raid5/cloudsat/2007/028/2007028184058_04011_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 342/4702: /bjerknes_raid5/cloudsat/2007/028/2007028170205_04010_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 343/4702: /bjerknes_raid5/cloudsat/2007/028/2007028084739_04005_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 344/4702: /bjerknes_raid5/cloudsat/2007/028/2007028215844_04013_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 345/4702: /bjerknes_raid5/cloudsat/2007/028/2007028021207_04001_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 346/4702: /bjerknes_raid5/cloudsat/2007/028/2007028201951_04012_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 347/4702: /bjerknes_raid5/cloudsat/2007/028/2007028233737_04014_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 348/4702: /bjerknes_raid5/cloudsat/2007/028/2007028035100_04002_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 349/4702: /bjerknes_raid5/cloudsat/2007/028/2007028003314_04000_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 350/4702: /bjerknes_raid5/cloudsat/2007/028/2007028070846_04004_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 351/4702: /bjerknes_raid5/cloudsat/2007/028/2007028134419_04008_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 352/4702: /bjerknes_raid5/cloudsat/2007/028/2007028152312_04009_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 353/4702: /bjerknes_raid5/cloudsat/2007/028/2007028120526_04007_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 354/4702: /bjerknes_raid5/cloudsat/2007/028/2007028052953_04003_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 355/4702: /bjerknes_raid5/cloudsat/2007/029/2007029124842_04022_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 356/4702: /bjerknes_raid5/cloudsat/2007/029/2007029025523_04016_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 357/4702: /bjerknes_raid5/cloudsat/2007/029/2007029142735_04023_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 358/4702: /bjerknes_raid5/cloudsat/2007/029/2007029043416_04017_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 359/4702: /bjerknes_raid5/cloudsat/2007/029/2007029192415_04026_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 360/4702: /bjerknes_raid5/cloudsat/2007/029/2007029224201_04028_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 361/4702: /bjerknes_raid5/cloudsat/2007/029/2007029160628_04024_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 362/4702: /bjerknes_raid5/cloudsat/2007/029/2007029174521_04025_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 363/4702: /bjerknes_raid5/cloudsat/2007/029/2007029110949_04021_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 364/4702: /bjerknes_raid5/cloudsat/2007/029/2007029061310_04018_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 365/4702: /bjerknes_raid5/cloudsat/2007/029/2007029093056_04020_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 366/4702: /bjerknes_raid5/cloudsat/2007/029/2007029210308_04027_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 367/4702: /bjerknes_raid5/cloudsat/2007/029/2007029075203_04019_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 368/4702: /bjerknes_raid5/cloudsat/2007/029/2007029011630_04015_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 369/4702: /bjerknes_raid5/cloudsat/2007/030/2007030033840_04031_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 370/4702: /bjerknes_raid5/cloudsat/2007/030/2007030015947_04030_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 371/4702: /bjerknes_raid5/cloudsat/2007/030/2007030002054_04029_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 372/4702: /bjerknes_raid5/cloudsat/2007/030/2007030200731_04041_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 373/4702: /bjerknes_raid5/cloudsat/2007/030/2007030232518_04043_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 374/4702: /bjerknes_raid5/cloudsat/2007/030/2007030115306_04036_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 375/4702: /bjerknes_raid5/cloudsat/2007/030/2007030051733_04032_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 376/4702: /bjerknes_raid5/cloudsat/2007/030/2007030164945_04039_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 377/4702: /bjerknes_raid5/cloudsat/2007/030/2007030065626_04033_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 378/4702: /bjerknes_raid5/cloudsat/2007/030/2007030151052_04038_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 379/4702: /bjerknes_raid5/cloudsat/2007/030/2007030101413_04035_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 380/4702: /bjerknes_raid5/cloudsat/2007/030/2007030214624_04042_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 381/4702: /bjerknes_raid5/cloudsat/2007/031/2007031105729_04050_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# ...
# Processing file 4581/4702: /bjerknes_raid5/cloudsat/2007/357/2007357070155_08795_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4582/4702: /bjerknes_raid5/cloudsat/2007/357/2007357165513_08801_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4583/4702: /bjerknes_raid5/cloudsat/2007/357/2007357233046_08805_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4584/4702: /bjerknes_raid5/cloudsat/2007/357/2007357151620_08800_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4585/4702: /bjerknes_raid5/cloudsat/2007/357/2007357002622_08791_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4586/4702: /bjerknes_raid5/cloudsat/2007/357/2007357183406_08802_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4587/4702: /bjerknes_raid5/cloudsat/2007/357/2007357052301_08794_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4588/4702: /bjerknes_raid5/cloudsat/2007/358/2007358092404_08811_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4589/4702: /bjerknes_raid5/cloudsat/2007/358/2007358060618_08809_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4590/4702: /bjerknes_raid5/cloudsat/2007/358/2007358223509_08819_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4591/4702: /bjerknes_raid5/cloudsat/2007/358/2007358074511_08810_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4592/4702: /bjerknes_raid5/cloudsat/2007/358/2007358173830_08816_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4593/4702: /bjerknes_raid5/cloudsat/2007/358/2007358024832_08807_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4594/4702: /bjerknes_raid5/cloudsat/2007/358/2007358042725_08808_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4595/4702: /bjerknes_raid5/cloudsat/2007/358/2007358155937_08815_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4596/4702: /bjerknes_raid5/cloudsat/2007/358/2007358142044_08814_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4597/4702: /bjerknes_raid5/cloudsat/2007/358/2007358010939_08806_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4598/4702: /bjerknes_raid5/cloudsat/2007/358/2007358205616_08818_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4599/4702: /bjerknes_raid5/cloudsat/2007/358/2007358110258_08812_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4600/4702: /bjerknes_raid5/cloudsat/2007/358/2007358191723_08817_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4601/4702: /bjerknes_raid5/cloudsat/2007/358/2007358124151_08813_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4602/4702: /bjerknes_raid5/cloudsat/2007/359/2007359213933_08833_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4603/4702: /bjerknes_raid5/cloudsat/2007/359/2007359033149_08822_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4604/4702: /bjerknes_raid5/cloudsat/2007/359/2007359051042_08823_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4605/4702: /bjerknes_raid5/cloudsat/2007/359/2007359231826_08834_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4606/4702: /bjerknes_raid5/cloudsat/2007/359/2007359100721_08826_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4607/4702: /bjerknes_raid5/cloudsat/2007/359/2007359001402_08820_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4608/4702: /bjerknes_raid5/cloudsat/2007/359/2007359082828_08825_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4609/4702: /bjerknes_raid5/cloudsat/2007/359/2007359164253_08830_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4610/4702: /bjerknes_raid5/cloudsat/2007/359/2007359114614_08827_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4611/4702: /bjerknes_raid5/cloudsat/2007/359/2007359182147_08831_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4612/4702: /bjerknes_raid5/cloudsat/2007/359/2007359132507_08828_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4613/4702: /bjerknes_raid5/cloudsat/2007/359/2007359150400_08829_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4614/4702: /bjerknes_raid5/cloudsat/2007/359/2007359015255_08821_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4615/4702: /bjerknes_raid5/cloudsat/2007/359/2007359200040_08832_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4616/4702: /bjerknes_raid5/cloudsat/2007/360/2007360154717_08844_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4617/4702: /bjerknes_raid5/cloudsat/2007/360/2007360222249_08848_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4618/4702: /bjerknes_raid5/cloudsat/2007/360/2007360172610_08845_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4619/4702: /bjerknes_raid5/cloudsat/2007/360/2007360005719_08835_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4620/4702: /bjerknes_raid5/cloudsat/2007/360/2007360073251_08839_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4621/4702: /bjerknes_raid5/cloudsat/2007/360/2007360091145_08840_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4622/4702: /bjerknes_raid5/cloudsat/2007/360/2007360105038_08841_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4623/4702: /bjerknes_raid5/cloudsat/2007/360/2007360041505_08837_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4624/4702: /bjerknes_raid5/cloudsat/2007/360/2007360055358_08838_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4625/4702: /bjerknes_raid5/cloudsat/2007/360/2007360190503_08846_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4626/4702: /bjerknes_raid5/cloudsat/2007/360/2007360140824_08843_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4627/4702: /bjerknes_raid5/cloudsat/2007/360/2007360023612_08836_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4628/4702: /bjerknes_raid5/cloudsat/2007/360/2007360204356_08847_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4629/4702: /bjerknes_raid5/cloudsat/2007/360/2007360122931_08842_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4630/4702: /bjerknes_raid5/cloudsat/2007/361/2007361095501_08855_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4631/4702: /bjerknes_raid5/cloudsat/2007/361/2007361045822_08852_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4632/4702: /bjerknes_raid5/cloudsat/2007/361/2007361180927_08860_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4633/4702: /bjerknes_raid5/cloudsat/2007/361/2007361031929_08851_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4634/4702: /bjerknes_raid5/cloudsat/2007/361/2007361145140_08858_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4635/4702: /bjerknes_raid5/cloudsat/2007/361/2007361000143_08849_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4636/4702: /bjerknes_raid5/cloudsat/2007/361/2007361081608_08854_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4637/4702: /bjerknes_raid5/cloudsat/2007/361/2007361014036_08850_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4638/4702: /bjerknes_raid5/cloudsat/2007/361/2007361113354_08856_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4639/4702: /bjerknes_raid5/cloudsat/2007/361/2007361230606_08863_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4640/4702: /bjerknes_raid5/cloudsat/2007/361/2007361194820_08861_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4641/4702: /bjerknes_raid5/cloudsat/2007/361/2007361063715_08853_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4642/4702: /bjerknes_raid5/cloudsat/2007/361/2007361212713_08862_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4643/4702: /bjerknes_raid5/cloudsat/2007/361/2007361131247_08857_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4644/4702: /bjerknes_raid5/cloudsat/2007/361/2007361163033_08859_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4645/4702: /bjerknes_raid5/cloudsat/2007/362/2007362135604_08872_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4646/4702: /bjerknes_raid5/cloudsat/2007/362/2007362085925_08869_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4647/4702: /bjerknes_raid5/cloudsat/2007/362/2007362234923_08878_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4648/4702: /bjerknes_raid5/cloudsat/2007/362/2007362004459_08864_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4649/4702: /bjerknes_raid5/cloudsat/2007/362/2007362185243_08875_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4650/4702: /bjerknes_raid5/cloudsat/2007/362/2007362072031_08868_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4651/4702: /bjerknes_raid5/cloudsat/2007/362/2007362121711_08871_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4652/4702: /bjerknes_raid5/cloudsat/2007/362/2007362203136_08876_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4653/4702: /bjerknes_raid5/cloudsat/2007/362/2007362103818_08870_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4654/4702: /bjerknes_raid5/cloudsat/2007/362/2007362022352_08865_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4655/4702: /bjerknes_raid5/cloudsat/2007/362/2007362171350_08874_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4656/4702: /bjerknes_raid5/cloudsat/2007/362/2007362054138_08867_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4657/4702: /bjerknes_raid5/cloudsat/2007/362/2007362153457_08873_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4658/4702: /bjerknes_raid5/cloudsat/2007/362/2007362221030_08877_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4659/4702: /bjerknes_raid5/cloudsat/2007/362/2007362040245_08866_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4660/4702: /bjerknes_raid5/cloudsat/2007/363/2007363112134_08885_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4661/4702: /bjerknes_raid5/cloudsat/2007/363/2007363094241_08884_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4662/4702: /bjerknes_raid5/cloudsat/2007/363/2007363225346_08892_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4663/4702: /bjerknes_raid5/cloudsat/2007/363/2007363161814_08888_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4664/4702: /bjerknes_raid5/cloudsat/2007/363/2007363062455_08882_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4665/4702: /bjerknes_raid5/cloudsat/2007/363/2007363130027_08886_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4666/4702: /bjerknes_raid5/cloudsat/2007/363/2007363030709_08880_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4667/4702: /bjerknes_raid5/cloudsat/2007/363/2007363080348_08883_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4668/4702: /bjerknes_raid5/cloudsat/2007/363/2007363012816_08879_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4669/4702: /bjerknes_raid5/cloudsat/2007/363/2007363193600_08890_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4670/4702: /bjerknes_raid5/cloudsat/2007/363/2007363211453_08891_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4671/4702: /bjerknes_raid5/cloudsat/2007/363/2007363044602_08881_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4672/4702: /bjerknes_raid5/cloudsat/2007/363/2007363143921_08887_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4673/4702: /bjerknes_raid5/cloudsat/2007/363/2007363175707_08889_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4674/4702: /bjerknes_raid5/cloudsat/2007/364/2007364052918_08896_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4675/4702: /bjerknes_raid5/cloudsat/2007/364/2007364233703_08907_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4676/4702: /bjerknes_raid5/cloudsat/2007/364/2007364134344_08901_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4677/4702: /bjerknes_raid5/cloudsat/2007/364/2007364152237_08902_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4678/4702: /bjerknes_raid5/cloudsat/2007/364/2007364215810_08906_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4679/4702: /bjerknes_raid5/cloudsat/2007/364/2007364070811_08897_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4680/4702: /bjerknes_raid5/cloudsat/2007/364/2007364170130_08903_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4681/4702: /bjerknes_raid5/cloudsat/2007/364/2007364120451_08900_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4682/4702: /bjerknes_raid5/cloudsat/2007/364/2007364084705_08898_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4683/4702: /bjerknes_raid5/cloudsat/2007/364/2007364184023_08904_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4684/4702: /bjerknes_raid5/cloudsat/2007/364/2007364201916_08905_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4685/4702: /bjerknes_raid5/cloudsat/2007/364/2007364102558_08899_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4686/4702: /bjerknes_raid5/cloudsat/2007/364/2007364021132_08894_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4687/4702: /bjerknes_raid5/cloudsat/2007/364/2007364003239_08893_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4688/4702: /bjerknes_raid5/cloudsat/2007/364/2007364035025_08895_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4689/4702: /bjerknes_raid5/cloudsat/2007/365/2007365224126_08921_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4690/4702: /bjerknes_raid5/cloudsat/2007/365/2007365025449_08909_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4691/4702: /bjerknes_raid5/cloudsat/2007/365/2007365061235_08911_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4692/4702: /bjerknes_raid5/cloudsat/2007/365/2007365174447_08918_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4693/4702: /bjerknes_raid5/cloudsat/2007/365/2007365210233_08920_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4694/4702: /bjerknes_raid5/cloudsat/2007/365/2007365110914_08914_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4695/4702: /bjerknes_raid5/cloudsat/2007/365/2007365124808_08915_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4696/4702: /bjerknes_raid5/cloudsat/2007/365/2007365160554_08917_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4697/4702: /bjerknes_raid5/cloudsat/2007/365/2007365011556_08908_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4698/4702: /bjerknes_raid5/cloudsat/2007/365/2007365043342_08910_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4699/4702: /bjerknes_raid5/cloudsat/2007/365/2007365192340_08919_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4700/4702: /bjerknes_raid5/cloudsat/2007/365/2007365142701_08916_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4701/4702: /bjerknes_raid5/cloudsat/2007/365/2007365075128_08912_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# Processing file 4702/4702: /bjerknes_raid5/cloudsat/2007/365/2007365093021_08913_CS_2B-FLXHR-LIDAR_GRANULE_P2_R05_E02_F00.hdf
# /tmp/ipykernel_53193/4128240586.py:47: RuntimeWarning: Mean of empty slice
#   aggregated_data[k, :, :, :] = np.nanmean(data_grid[day_indices, :, :, :], axis=0)
# /tmp/ipykernel_53193/3031461719.py:102: RuntimeWarning: Mean of empty slice
#   QR_SWcloud_dia_grid_daily_zonalmean = np.nanmean(QR_SWcloud_dia_grid_daily, axis=2)
# /tmp/ipykernel_53193/3031461719.py:103: RuntimeWarning: Mean of empty slice
#   QR_LWcloud_dia_grid_daily_zonalmean = np.nanmean(QR_LWcloud_dia_grid_daily, axis=2)
# Processing complete. Data saved to QR_cloud_2007.npz

# %% [markdown]
# ### load QR_cloud_2007.npz and convert it to a netcdf file

# %%
CRH_binned = np.load('QR_cloud_2007.npz', allow_pickle=True)
CRHlw_grid_daily_zonalmean = CRH_binned['QR_LWcloud_dia_grid_daily_zonalmean']
CRHsw_grid_daily_zonalmean = CRH_binned['QR_SWcloud_dia_grid_daily_zonalmean']
CRH_grid_daily_zonalmean = CRHlw_grid_daily_zonalmean + CRHsw_grid_daily_zonalmean

# %%
# Define coordinates (you may need to adapt these based on your data)
alt_grid = CRH_binned['alt_grid']
new_lat = CRH_binned['new_lat']
time = CRH_binned['numdate']  # Assuming numdate holds time information

# Create an xarray DataArray
CRHlw_grid_da = xr.DataArray(
    CRHlw_grid_daily_zonalmean,
    coords={'time': time, 'height': alt_grid, 'lat': new_lat},
    dims=['time', 'lat', 'height'],
    name='CRH_LWcloud'
)

CRHlw_grid_da.to_netcdf('/bjerknes_raid5/cloudsat/CRH_LW_CloudSat_2007.nc')

# %%
CRH_binned = np.load('QR_cloud_2007.npz', allow_pickle=True)
CRHlw_grid_daily_zonalmean = CRH_binned['QR_LWcloud_dia_grid_daily_zonalmean']
CRHsw_grid_daily_zonalmean = CRH_binned['QR_SWcloud_dia_grid_daily_zonalmean']
CRH_grid_daily_zonalmean = CRHlw_grid_daily_zonalmean + CRHsw_grid_daily_zonalmean

alt_grid = CRH_binned['alt_grid']
new_lat = CRH_binned['new_lat']
time = CRH_binned['numdate']  # Assuming numdate holds time information

# Create an xarray DataArray
CRHlw_grid_da = xr.DataArray(
    CRHlw_grid_daily_zonalmean,
    coords={'time': time, 'height': alt_grid, 'lat': new_lat},
    dims=['time', 'lat', 'height'],
    name='CRH_LWcloud'
)

CRHlw_grid_da.to_netcdf('/bjerknes_raid5/cloudsat/CRH_LW_CloudSat_2007.nc')

# %% [markdown]
# other years can be processed in a simlar way...

# %% [markdown]
# #### combine years together

# %%
file_2007 = xr.open_dataset("/bjerknes_raid5/cloudsat/CRH_LW_CloudSat_2007.nc")
file_2008 = xr.open_dataset("/bjerknes_raid5/cloudsat/CRH_LW_CloudSat_2008.nc")
file_2009 = xr.open_dataset("/bjerknes_raid5/cloudsat/CRH_LW_CloudSat_2009.nc")
file_2010 = xr.open_dataset("/bjerknes_raid5/cloudsat/CRH_LW_CloudSat_2010.nc")

# Concatenate the datasets along the time dimension
combined = xr.concat([file_2007, file_2008, file_2009, file_2010], dim="time")

# Save the combined dataset to a new NetCDF file
combined.to_netcdf("../data/CRH_LW_CloudSat_combined.nc")
